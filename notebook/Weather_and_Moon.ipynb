# %%
import pandas as pd
import numpy as np

# %%
moon = pd.read_csv('C:\Users\cathe\Documents\Python docs\UFO_sightings\UFO-Sightings-Analysis\data\moon_phase_data.csv') #read in moon phases
weather = pd.read_csv('C:\Users\cathe\Documents\Python docs\UFO_sightings\UFO-Sightings-Analysis\data\weather.csv')

# %%
weather['STATE'] = weather['STATE'].str.lower() #make states lowercase to match the other data

# %%
ufo_atmosphere = pd.merge(moon, weather, left_on=[moon.state, moon.date], right_on=[weather.STATE, weather.Date], how='left')
ufo_atmosphere[:20]
# Out:
#    key_0       key_1  Unnamed: 0    datetime              city state country  \
# 0     ny  1970-10-10           0  1970-10-10          bellmore    ny      us
# 1     ky  1970-10-10           1  1970-10-10        manchester    ky      us
# 2     nc  1971-10-10           2  1971-10-10         lexington    nc      us
# 3     ky  1972-10-10           3  1972-10-10     harlan county    ky      us
# 4     mi  1972-10-10           4  1972-10-10   west bloomfield    mi      us
# 5     ct  1973-10-10           5  1973-10-10           niantic    ct      us
# 6     ma  1974-10-10           6  1974-10-10            hudson    ma      us
# 7     ks  1974-10-10           7  1974-10-10            hudson    ks      us
# 8     sc  1975-10-10           8  1975-10-10  north charleston    sc      us
# 9     wa  1976-10-10           9  1976-10-10         washougal    wa      us
# 10    tx  1977-10-10          10  1977-10-10       san antonio    tx      us
# 11    ky  1977-10-10          11  1977-10-10        louisville    ky      us
# 12    ny  1978-10-10          12  1978-10-10            elmont    ny      us
# 13    ny  1979-10-10          13  1979-10-10      poughkeepsie    ny      us
# 14    ca  1979-10-10          14  1979-10-10         san diego    ca      us
# 15    co  1979-10-10          15  1979-10-10          security    co      us
# 16    tx  1980-10-10          16  1980-10-10           houston    tx      us
# 17    tx  1980-10-10          17  1980-10-10            dallas    tx      us
# 18    nh  1980-10-10          18  1980-10-10        manchester    nh      us
# 19    tx  1984-10-10          19  1984-10-10           houston    tx      us
#
#         shape  duration (seconds) duration (hours/min)    ...       latitude  \
# 0        disk              1800.0              30 min.    ...      40.668611
# 1     unknown               180.0            3 minutes    ...      37.153611
# 2        oval                30.0           30 seconds    ...      35.823889
# 3      circle              1200.0            20minutes    ...      36.843056
# 4        disk               120.0            2 minutes    ...      42.537778
# 5        disk              1800.0            20-30 min    ...      41.325278
# 6       other              2700.0           45 minutes    ...      42.391667
# 7       light              1200.0            one hour?    ...      38.105556
# 8       light               360.0          5-6 minutes    ...      32.854444
# 9        oval                60.0             1 minute    ...      45.582778
# 10      other                30.0           30 seconds    ...      29.423889
# 11      light                30.0   approx: 30 seconds    ...      38.254167
# 12  rectangle               300.0                 5min    ...      40.700833
# 13    chevron               900.0           15 minutes    ...      41.700278
# 14       oval               180.0            3 minutes    ...      32.715278
# 15    unknown              1800.0              30mins.    ...      38.758333
# 16     sphere               180.0                3 min    ...      29.763056
# 17    unknown               300.0            5 minutes    ...      32.783333
# 18      light               300.0           3 to 5 min    ...      42.995556
# 19     circle                60.0             1 minute    ...      29.763056
#
#     longitude   label  index        date          phase phaseid        Date  \
# 0   -73.527500      0     12  1970-10-10  First Quarter       2         NaN
# 1   -83.761944      0     13  1970-10-10  First Quarter       2         NaN
# 2   -80.253611      0     14  1971-10-10      Full Moon       3         NaN
# 3   -83.321944      0     15  1972-10-10       New Moon       1         NaN
# 4   -83.233056      0     16  1972-10-10       New Moon       1         NaN
# 5   -72.193611      0     17  1973-10-10  First Quarter       2         NaN
# 6   -71.566667      0     19  1974-10-10   Last Quarter       4         NaN
# 7   -98.659722      0     21  1974-10-10   Last Quarter       4         NaN
# 8   -79.975000      0     22  1975-10-10       New Moon       1         NaN
# 9  -122.352222      0     23  1976-10-10      Full Moon       3         NaN
# 10  -98.493333      0     25  1977-10-10   Last Quarter       4         NaN
# 11  -85.759444      0     26  1977-10-10   Last Quarter       4         NaN
# 12  -73.713333      0     27  1978-10-10  First Quarter       2         NaN
# 13  -73.921389      0     28  1979-10-10      Full Moon       3         NaN
# 14 -117.156389      0     30  1979-10-10      Full Moon       3         NaN
# 15 -104.742500      0     31  1979-10-10      Full Moon       3         NaN
# 16  -95.363056      0     32  1980-10-10       New Moon       1         NaN
# 17  -96.800000      0     33  1980-10-10       New Moon       1         NaN
# 18  -71.455278      0     34  1980-10-10       New Moon       1         NaN
# 19  -95.363056      0     36  1984-10-10      Full Moon       3  1984-10-10
#
#     STATE EVENT_TYPE
# 0     NaN        NaN
# 1     NaN        NaN
# 2     NaN        NaN
# 3     NaN        NaN
# 4     NaN        NaN
# 5     NaN        NaN
# 6     NaN        NaN
# 7     NaN        NaN
# 8     NaN        NaN
# 9     NaN        NaN
# 10    NaN        NaN
# 11    NaN        NaN
# 12    NaN        NaN
# 13    NaN        NaN
# 14    NaN        NaN
# 15    NaN        NaN
# 16    NaN        NaN
# 17    NaN        NaN
# 18    NaN        NaN
# 19     tx       Hail
#
# [20 rows x 22 columns]
